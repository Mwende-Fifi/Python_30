# %% [markdown]
# ### Welcome Day 17 of 30 days python
#
# Data Cleaning with Pandas
# - Handling missing data (drop, fillna)
# - Removing duplicates
# - Renaming and formatting columns

# %%
# importing dependencies
import pandas as pd
import xlrd
import openpyxl

# %% [markdown]
# 1. **Filtering**: Filter the DataFrame to show only employees who work in the "IT" department.

# %%
df_emp = pd.read_csv('day16_sample_emp.csv')

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          21 non-null     object
#  1   Full Name   21 non-null     object
#  2   Department  21 non-null     object
#  3   Salary      21 non-null     object
#  4   Age         21 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 972.0+ bytes

# %%
df_emp.columns
# Out:
# Index(['ID', 'Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
df_emp['Department'] == 'IT'
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# 20    False
# Name: Department, dtype: bool

# %%
df_emp[df_emp['Department'] == 'IT']
# Out:
#         ID        Full Name Department     Salary  Age
# 2   E02004       Cameron Lo         IT   $83,576    34
# 3   E02005  Harper Castillo         IT   $98,062    39
# 6   E02010    Gianna Holmes         IT   $97,630    38
# 8   E02012     Jameson Pena         IT   $40,499    49
# 10  E02014        Jose Wong         IT  $150,558    45
# 13  E02017          Luna Lu         IT   $64,208    62
# 16  E02020     Jordan Kumar         IT   $95,729    29
# 19  E02023    Lillian Lewis         IT   $83,323    43

# %% [markdown]
# 2. **Filtering**: Filter the DataFrame to show only female employees who are older than 50.

# %%
df_emp2 = pd.read_csv('day16_emp_data.csv')
df_emp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          23 non-null     object
#  1   Full Name   21 non-null     object
#  2   Job Title   18 non-null     object
#  3   Department  21 non-null     object
#  4   Gender      21 non-null     object
#  5   Age         21 non-null     float64
#  6   Hire Date   14 non-null     object
#  7   Salary      21 non-null     object
#  8   Country     17 non-null     object
#  9   City        23 non-null     object
#  10  Exit Date   2 non-null      object
# dtypes: float64(1), object(10)
# memory usage: 2.1+ KB

# %%
df_emp2.head()
# Out:
#        ID        Full Name              Job Title   Department  Gender   Age  \
# 0  E02002           Kai Le      Controls Engineer  Engineering    Male  47.0
# 1  E02003     Robert Patel                Analyst        Sales    Male  58.0
# 2  E02004       Cameron Lo  Network Administrator           IT    Male  34.0
# 3  E02005  Harper Castillo   IT Systems Architect           IT  Female  39.0
# 4  E02006              NaN                    NaN          NaN     NaN   NaN
#
#     Hire Date    Salary        Country      City Exit Date
# 0    02/05/22  $92,368   United States  Columbus       NaN
# 1  10/23/2013  $45,703   United States   Chicago       NaN
# 2   3/24/2019  $83,576           China  Shanghai       NaN
# 3    04/07/18  $98,062   United States   Seattle       NaN
# 4         NaN       NaN            NaN    Austin       NaN

# %%
df_emp2[(df_emp2['Gender'] == 'Female') & (df_emp2['Age'] > 50)]
# Out:
#         ID         Full Name             Job Title  Department  Gender   Age  \
# 6   E02008           Jade Hu           Sr. Analyst  Accounting  Female  58.0
# 11  E02013          Bella Wu                   NaN     Finance  Female  63.0
# 15  E02017           Luna Lu  IT Systems Architect          IT  Female  62.0
# 17  E02019          Ivy Chau               Analyst       Sales  Female  61.0
# 19  E02021  Sophia Gutierrez               Manager  Accounting  Female  63.0
#
#     Hire Date     Salary        Country       City Exit Date
# 6   6/27/2009   $89,744           China  Chongqing       NaN
# 11        NaN   $71,418             NaN    Phoenix       NaN
# 15        NaN   $64,208   United States      Miami       NaN
# 17        NaN   $54,811           China  Chongqing       NaN
# 19   02/08/09  $102,649   United States     Austin       NaN

# %% [markdown]
# 3. **Sorting**: Sort the DataFrame by the "Age" column in descending order.

# %%
df_emp.sort_values(by=['Age'], ascending=[False])
# Out:
#         ID         Full Name   Department     Salary  Age
# 17  E02021  Sophia Gutierrez   Accounting  $102,649    63
# 9   E02013          Bella Wu      Finance   $71,418    63
# 13  E02017           Luna Lu           IT   $64,208    62
# 5   E02009       Miles Chang      Finance   $69,674    62
# 15  E02019          Ivy Chau        Sales   $54,811    61
# 4   E02008           Jade Hu   Accounting   $89,744    58
# 1   E02003      Robert Patel        Sales   $45,703    58
# 7   E02011    Jameson Thomas      Finance  $105,879    52
# 8   E02012      Jameson Pena           IT   $40,499    49
# 0   E02002            Kai Le  Engineering   $92,368    47
# 18  E02022          Eli Dang   Accounting  $122,875    45
# 14  E02018        Bella Tran  Engineering  $254,486    45
# 10  E02014         Jose Wong           IT  $150,558    45
# 19  E02023     Lillian Lewis           IT   $83,323    43
# 12  E02016       Jacob Moore    Marketing  $131,422    42
# 3   E02005   Harper Castillo           IT   $98,062    39
# 6   E02010     Gianna Holmes           IT   $97,630    38
# 11  E02015  Lucas Richardson    Marketing  $118,912    36
# 2   E02004        Cameron Lo           IT   $83,576    34
# 20  E02024      Serenity Cao        Sales   $66,721    31
# 16  E02020      Jordan Kumar           IT   $95,729    29

# %% [markdown]
# 4. **Sorting**: Sort the DataFrame first by "Department" (ascending) and then by "Age" (descending).

# %%
df_emp2.sort_values(by=['Department', 'Age'], ascending=[True, False])
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 19  E02021  Sophia Gutierrez                 Manager   Accounting  Female
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 20  E02022          Eli Dang             Sr. Manager   Accounting    Male
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 16  E02018        Bella Tran          Vice President  Engineering  Female
# 11  E02013          Bella Wu                     NaN      Finance  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 15  E02017           Luna Lu    IT Systems Architect           IT  Female
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 12  E02014         Jose Wong                     NaN           IT    Male
# 21  E02023     Lillian Lewis     Technical Architect           IT  Female
# 3   E02005   Harper Castillo    IT Systems Architect           IT  Female
# 8   E02010     Gianna Holmes   System Administrator†           IT  Female
# 2   E02004        Cameron Lo   Network Administrator           IT    Male
# 18  E02020      Jordan Kumar    Service Desk Analyst           IT    Male
# 14  E02016       Jacob Moore             Sr. Manager    Marketing    Male
# 13  E02015  Lucas Richardson                     NaN    Marketing    Male
# 17  E02019          Ivy Chau                 Analyst        Sales  Female
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 22  E02024      Serenity Cao  Account Representative        Sales  Female
# 4   E02006               NaN                     NaN          NaN     NaN
# 5   E02007               NaN                     NaN          NaN     NaN
#
#      Age   Hire Date     Salary        Country       City  Exit Date
# 19  63.0    02/08/09  $102,649   United States     Austin        NaN
# 6   58.0   6/27/2009   $89,744           China  Chongqing        NaN
# 20  45.0  11/16/2015  $122,875   United States    Chicago        NaN
# 0   47.0    02/05/22   $92,368   United States   Columbus        NaN
# 16  45.0         NaN  $254,486           China    Chengdu        NaN
# 11  63.0         NaN   $71,418             NaN    Phoenix        NaN
# 7   62.0   2/19/1999   $69,674           China    Chengdu        NaN
# 9   52.0    02/05/15  $105,879   United States      Miami        NaN
# 15  62.0         NaN   $64,208   United States      Miami        NaN
# 10  49.0    10/12/03   $40,499   United States      Miami        NaN
# 12  45.0         NaN  $150,558             NaN  Chongqing        NaN
# 21  43.0   8/14/2013   $83,323   United States    Phoenix  3/31/2019
# 3   39.0    04/07/18   $98,062   United States    Seattle        NaN
# 8   38.0    09/09/11   $97,630   United States    Seattle        NaN
# 2   34.0   3/24/2019   $83,576           China   Shanghai        NaN
# 18  29.0    11/11/17   $95,729   United States    Seattle        NaN
# 14  42.0         NaN  $131,422             NaN    Phoenix        NaN
# 13  36.0         NaN  $118,912             NaN      Miami        NaN
# 17  61.0         NaN   $54,811           China  Chongqing        NaN
# 1   58.0  10/23/2013   $45,703   United States    Chicago        NaN
# 22  31.0  10/21/2018   $66,721           China   Shanghai        NaN
# 4    NaN         NaN        NaN            NaN     Austin        NaN
# 5    NaN         NaN        NaN            NaN    Phoenix  2/14/2014

# %% [markdown]
# 5. **Indexing**: Set the "ID" column as the index of the DataFrame and display the first 5 rows.

# %%
df_emp.iloc[0:5]
# Out:
#        ID        Full Name   Department    Salary  Age
# 0  E02002           Kai Le  Engineering  $92,368    47
# 1  E02003     Robert Patel        Sales  $45,703    58
# 2  E02004       Cameron Lo           IT  $83,576    34
# 3  E02005  Harper Castillo           IT  $98,062    39
# 4  E02008          Jade Hu   Accounting  $89,744    58

# %%
new_df_emp = df_emp.set_index('ID')

# %%
new_df_emp
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02002            Kai Le  Engineering   $92,368    47
# E02003      Robert Patel        Sales   $45,703    58
# E02004        Cameron Lo           IT   $83,576    34
# E02005   Harper Castillo           IT   $98,062    39
# E02008           Jade Hu   Accounting   $89,744    58
# E02009       Miles Chang      Finance   $69,674    62
# E02010     Gianna Holmes           IT   $97,630    38
# E02011    Jameson Thomas      Finance  $105,879    52
# E02012      Jameson Pena           IT   $40,499    49
# E02013          Bella Wu      Finance   $71,418    63
# E02014         Jose Wong           IT  $150,558    45
# E02015  Lucas Richardson    Marketing  $118,912    36
# E02016       Jacob Moore    Marketing  $131,422    42
# E02017           Luna Lu           IT   $64,208    62
# E02018        Bella Tran  Engineering  $254,486    45
# E02019          Ivy Chau        Sales   $54,811    61
# E02020      Jordan Kumar           IT   $95,729    29
# E02021  Sophia Gutierrez   Accounting  $102,649    63
# E02022          Eli Dang   Accounting  $122,875    45
# E02023     Lillian Lewis           IT   $83,323    43
# E02024      Serenity Cao        Sales   $66,721    31

# %%
new_df_emp.loc['E02002':'E02008']
# Out:
#               Full Name   Department    Salary  Age
# ID
# E02002           Kai Le  Engineering  $92,368    47
# E02003     Robert Patel        Sales  $45,703    58
# E02004       Cameron Lo           IT  $83,576    34
# E02005  Harper Castillo           IT  $98,062    39
# E02008          Jade Hu   Accounting  $89,744    58

# %% [markdown]
# 6. **Indexing**: Select the "Full Name" and "Job Title" columns for the employee with the ID "E02011".

# %%
df_emp2
# Out:
#         ID         Full Name               Job Title   Department  Gender  \
# 0   E02002            Kai Le       Controls Engineer  Engineering    Male
# 1   E02003      Robert Patel                 Analyst        Sales    Male
# 2   E02004        Cameron Lo   Network Administrator           IT    Male
# 3   E02005   Harper Castillo    IT Systems Architect           IT  Female
# 4   E02006               NaN                     NaN          NaN     NaN
# 5   E02007               NaN                     NaN          NaN     NaN
# 6   E02008           Jade Hu             Sr. Analyst   Accounting  Female
# 7   E02009       Miles Chang              Analyst II      Finance    Male
# 8   E02010     Gianna Holmes   System Administrator†           IT  Female
# 9   E02011    Jameson Thomas                 Manager      Finance    Male
# 10  E02012      Jameson Pena         Systems Analyst           IT    Male
# 11  E02013          Bella Wu                     NaN      Finance  Female
# 12  E02014         Jose Wong                     NaN           IT    Male
# 13  E02015  Lucas Richardson                     NaN    Marketing    Male
# 14  E02016       Jacob Moore             Sr. Manager    Marketing    Male
# 15  E02017           Luna Lu    IT Systems Architect           IT  Female
# 16  E02018        Bella Tran          Vice President  Engineering  Female
# 17  E02019          Ivy Chau                 Analyst        Sales  Female
# 18  E02020      Jordan Kumar    Service Desk Analyst           IT    Male
# 19  E02021  Sophia Gutierrez                 Manager   Accounting  Female
# 20  E02022          Eli Dang             Sr. Manager   Accounting    Male
# 21  E02023     Lillian Lewis     Technical Architect           IT  Female
# 22  E02024      Serenity Cao  Account Representative        Sales  Female
#
#      Age   Hire Date     Salary        Country       City  Exit Date
# 0   47.0    02/05/22   $92,368   United States   Columbus        NaN
# 1   58.0  10/23/2013   $45,703   United States    Chicago        NaN
# 2   34.0   3/24/2019   $83,576           China   Shanghai        NaN
# 3   39.0    04/07/18   $98,062   United States    Seattle        NaN
# 4    NaN         NaN        NaN            NaN     Austin        NaN
# 5    NaN         NaN        NaN            NaN    Phoenix  2/14/2014
# 6   58.0   6/27/2009   $89,744           China  Chongqing        NaN
# 7   62.0   2/19/1999   $69,674           China    Chengdu        NaN
# 8   38.0    09/09/11   $97,630   United States    Seattle        NaN
# 9   52.0    02/05/15  $105,879   United States      Miami        NaN
# 10  49.0    10/12/03   $40,499   United States      Miami        NaN
# 11  63.0         NaN   $71,418             NaN    Phoenix        NaN
# 12  45.0         NaN  $150,558             NaN  Chongqing        NaN
# 13  36.0         NaN  $118,912             NaN      Miami        NaN
# 14  42.0         NaN  $131,422             NaN    Phoenix        NaN
# 15  62.0         NaN   $64,208   United States      Miami        NaN
# 16  45.0         NaN  $254,486           China    Chengdu        NaN
# 17  61.0         NaN   $54,811           China  Chongqing        NaN
# 18  29.0    11/11/17   $95,729   United States    Seattle        NaN
# 19  63.0    02/08/09  $102,649   United States     Austin        NaN
# 20  45.0  11/16/2015  $122,875   United States    Chicago        NaN
# 21  43.0   8/14/2013   $83,323   United States    Phoenix  3/31/2019
# 22  31.0  10/21/2018   $66,721           China   Shanghai        NaN

# %%
df_emp2[df_emp2['ID'] == 'E02011'][['Full Name', 'Job Title']]
# Out:
#         Full Name Job Title
# 9  Jameson Thomas   Manager

# %%
df = df_emp2[df_emp2['ID'] == 'E02011']
df[['Full Name', 'Job Title']]
# Out:
#         Full Name Job Title
# 9  Jameson Thomas   Manager

# %% [markdown]
# 7. **Exporting**: Export the DataFrame to a new CSV file named "employee_data.csv".

# %%
df[['Full Name', 'Job Title']].to_csv('emp_data_1.csv')

# %% [markdown]
# ### Problems for Walmart dataset

# %% [markdown]
# 1. **Filtering**: Filter the DataFrame to show only transactions where the customer type is "Member".

# %%
df = pd.read_excel('day16_walmart.xlsx')
df.head()
# Out:
#     invoice_id branch          city customer_type  age  gender  \
# 0  750-67-8428      D      San Jose        Member   40  Female
# 1  226-31-3081      A  Philadelphia        Normal   29  Female
# 2  631-41-3108      A       Phoenix        Normal   28    Male
# 3  123-19-1176      B      New York        Member   27    Male
# 4  373-73-7910      A       Chicago        Normal   52    Male
#
#              product_line  unit_price     total       date payment_method  \
# 0       Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 1  Electronic accessories       15.28   80.2200 2019-03-08           Cash
# 2      Home and lifestyle       46.33  340.5255 2019-03-03    Credit card
# 3       Health and beauty       58.22  489.0480 2019-01-27        Ewallet
# 4       Sports and travel       86.31  634.3785 2019-02-08        Ewallet
#
#    rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      19 non-null     object
#  1   branch          19 non-null     object
#  2   city            19 non-null     object
#  3   customer_type   19 non-null     object
#  4   age             19 non-null     int64
#  5   gender          19 non-null     object
#  6   product_line    19 non-null     object
#  7   unit_price      19 non-null     float64
#  8   total           19 non-null     float64
#  9   date            19 non-null     datetime64[ns]
#  10  payment_method  19 non-null     object
#  11  rating          19 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(7)
# memory usage: 1.9+ KB

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'age', 'gender',
#        'product_line', 'unit_price', 'total', 'date', 'payment_method',
#        'rating'],
#       dtype='object')

# %%
df[df['customer_type'] == 'Member']
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 0   750-67-8428      D      San Jose        Member   40  Female
# 3   123-19-1176      B      New York        Member   27    Male
# 6   355-53-5943      C   Los Angeles        Member   34  Female
# 8   665-32-9167      A      New York        Member   66  Female
# 9   692-92-5582      A  Philadelphia        Member   56  Female
# 10  351-62-0822      D       Chicago        Member   60  Female
# 11  529-56-3974      A        Dallas        Member   46    Male
# 15  299-46-1805      B      New York        Member   39  Female
# 16  656-95-9349      B   Los Angeles        Member   46  Female
#
#               product_line  unit_price     total       date payment_method  \
# 0        Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 3        Health and beauty       58.22  489.0480 2019-01-27        Ewallet
# 6   Electronic accessories       68.84  433.6920 2019-02-25        Ewallet
# 8        Health and beauty       36.26   76.1460 2019-01-10    Credit card
# 9       Food and beverages       54.84  172.7460 2019-02-20    Credit card
# 10     Fashion accessories       14.48   60.8160 2019-02-06        Ewallet
# 11  Electronic accessories       25.51  107.1420 2019-03-09           Cash
# 15       Sports and travel       93.72  590.4360 2019-01-15           Cash
# 16       Health and beauty       68.93  506.6355 2019-03-11    Credit card
#
#     rating
# 0      9.1
# 3      8.4
# 6      5.8
# 8      7.2
# 9      5.9
# 10     4.5
# 11     6.8
# 15     4.5
# 16     4.6

# %% [markdown]
# 2. **Filtering**: Filter the DataFrame to show transactions where the total amount is greater than $500.

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'age', 'gender',
#        'product_line', 'unit_price', 'total', 'date', 'payment_method',
#        'rating'],
#       dtype='object')

# %%
df[df['total'] > 500]
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 0   750-67-8428      D      San Jose        Member   40  Female
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 5   699-14-3026      B  Philadelphia        Normal   54    Male
# 7   315-22-5665      D  Philadelphia        Normal   33  Female
# 14  829-34-3910      C     San Diego        Normal   24  Female
# 15  299-46-1805      B      New York        Member   39  Female
# 16  656-95-9349      B   Los Angeles        Member   46  Female
#
#               product_line  unit_price     total       date payment_method  \
# 0        Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 4        Sports and travel       86.31  634.3785 2019-02-08        Ewallet
# 5   Electronic accessories       85.39  627.6165 2019-03-25        Ewallet
# 7       Home and lifestyle       73.56  772.3800 2019-02-24        Ewallet
# 14       Health and beauty       71.38  749.4900 2019-03-29           Cash
# 15       Sports and travel       93.72  590.4360 2019-01-15           Cash
# 16       Health and beauty       68.93  506.6355 2019-03-11    Credit card
#
#     rating
# 0      9.1
# 4      5.3
# 5      4.1
# 7      8.0
# 14     5.7
# 15     4.5
# 16     4.6

# %% [markdown]
# 3. **Sorting**: Sort the DataFrame by the "total" column in descending order to find the highest transactions.

# %%
df.sort_values(by='total', ascending=False, inplace=True)

# %%
df.head()
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 7   315-22-5665      D  Philadelphia        Normal   33  Female
# 14  829-34-3910      C     San Diego        Normal   24  Female
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 5   699-14-3026      B  Philadelphia        Normal   54    Male
# 15  299-46-1805      B      New York        Member   39  Female
#
#               product_line  unit_price     total       date payment_method  \
# 7       Home and lifestyle       73.56  772.3800 2019-02-24        Ewallet
# 14       Health and beauty       71.38  749.4900 2019-03-29           Cash
# 4        Sports and travel       86.31  634.3785 2019-02-08        Ewallet
# 5   Electronic accessories       85.39  627.6165 2019-03-25        Ewallet
# 15       Sports and travel       93.72  590.4360 2019-01-15           Cash
#
#     rating
# 7      8.0
# 14     5.7
# 4      5.3
# 5      4.1
# 15     4.5

# %% [markdown]
# 4. **Sorting**: Sort the DataFrame first by "branch" (ascending) and then by "unit_price" (descending).

# %%
df.sort_values(by=['branch', 'unit_price'], ascending=[True, False])
# Out:
#      invoice_id branch          city customer_type  age  gender  \
# 4   373-73-7910      A       Chicago        Normal   52    Male
# 9   692-92-5582      A  Philadelphia        Member   56  Female
# 2   631-41-3108      A       Phoenix        Normal   28    Male
# 8   665-32-9167      A      New York        Member   66  Female
# 11  529-56-3974      A        Dallas        Member   46    Male
# 1   226-31-3081      A  Philadelphia        Normal   29  Female
# 15  299-46-1805      B      New York        Member   39  Female
# 5   699-14-3026      B  Philadelphia        Normal   54    Male
# 16  656-95-9349      B   Los Angeles        Member   46  Female
# 3   123-19-1176      B      New York        Member   27    Male
# 13  252-56-2699      B       Chicago        Normal   35    Male
# 17  765-26-6951      C       Houston        Normal   33    Male
# 14  829-34-3910      C     San Diego        Normal   24  Female
# 6   355-53-5943      C   Los Angeles        Member   34  Female
# 18  329-62-1586      C       Phoenix        Normal   54    Male
# 12  365-64-0515      C      New York        Normal   55  Female
# 0   750-67-8428      D      San Jose        Member   40  Female
# 7   315-22-5665      D  Philadelphia        Normal   33  Female
# 10  351-62-0822      D       Chicago        Member   60  Female
#
#               product_line  unit_price     total       date payment_method  \
# 4        Sports and travel       86.31  634.3785 2019-02-08        Ewallet
# 9       Food and beverages       54.84  172.7460 2019-02-20    Credit card
# 2       Home and lifestyle       46.33  340.5255 2019-03-03    Credit card
# 8        Health and beauty       36.26   76.1460 2019-01-10    Credit card
# 11  Electronic accessories       25.51  107.1420 2019-03-09           Cash
# 1   Electronic accessories       15.28   80.2200 2019-03-08           Cash
# 15       Sports and travel       93.72  590.4360 2019-01-15           Cash
# 5   Electronic accessories       85.39  627.6165 2019-03-25        Ewallet
# 16       Health and beauty       68.93  506.6355 2019-03-11    Credit card
# 3        Health and beauty       58.22  489.0480 2019-01-27        Ewallet
# 13      Food and beverages       43.19  453.4950 2019-02-07        Ewallet
# 17       Sports and travel       72.61  457.4430 2019-01-01    Credit card
# 14       Health and beauty       71.38  749.4900 2019-03-29           Cash
# 6   Electronic accessories       68.84  433.6920 2019-02-25        Ewallet
# 18      Food and beverages       54.67  172.2105 2019-01-21    Credit card
# 12  Electronic accessories       46.95  246.4875 2019-02-12        Ewallet
# 0        Health and beauty       74.69  548.9715 2019-01-05        Ewallet
# 7       Home and lifestyle       73.56  772.3800 2019-02-24        Ewallet
# 10     Fashion accessories       14.48   60.8160 2019-02-06        Ewallet
#
#     rating
# 4      5.3
# 9      5.9
# 2      7.4
# 8      7.2
# 11     6.8
# 1      9.6
# 15     4.5
# 5      4.1
# 16     4.6
# 3      8.4
# 13     8.2
# 17     6.9
# 14     5.7
# 6      5.8
# 18     8.6
# 12     7.1
# 0      9.1
# 7      8.0
# 10     4.5

# %% [markdown]
# 5. **Indexing**: Set the "invoice_id" column as the index of the DataFrame and display the first 5 rows.

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'age', 'gender',
#        'product_line', 'unit_price', 'total', 'date', 'payment_method',
#        'rating'],
#       dtype='object')

# %%
df_new = df.set_index('invoice_id')
df_new
# Out:
#             branch          city customer_type  age  gender  \
# invoice_id
# 315-22-5665      D  Philadelphia        Normal   33  Female
# 829-34-3910      C     San Diego        Normal   24  Female
# 373-73-7910      A       Chicago        Normal   52    Male
# 699-14-3026      B  Philadelphia        Normal   54    Male
# 299-46-1805      B      New York        Member   39  Female
# 750-67-8428      D      San Jose        Member   40  Female
# 656-95-9349      B   Los Angeles        Member   46  Female
# 123-19-1176      B      New York        Member   27    Male
# 765-26-6951      C       Houston        Normal   33    Male
# 252-56-2699      B       Chicago        Normal   35    Male
# 355-53-5943      C   Los Angeles        Member   34  Female
# 631-41-3108      A       Phoenix        Normal   28    Male
# 365-64-0515      C      New York        Normal   55  Female
# 692-92-5582      A  Philadelphia        Member   56  Female
# 329-62-1586      C       Phoenix        Normal   54    Male
# 529-56-3974      A        Dallas        Member   46    Male
# 226-31-3081      A  Philadelphia        Normal   29  Female
# 665-32-9167      A      New York        Member   66  Female
# 351-62-0822      D       Chicago        Member   60  Female
#
#                        product_line  unit_price     total       date  \
# invoice_id
# 315-22-5665      Home and lifestyle       73.56  772.3800 2019-02-24
# 829-34-3910       Health and beauty       71.38  749.4900 2019-03-29
# 373-73-7910       Sports and travel       86.31  634.3785 2019-02-08
# 699-14-3026  Electronic accessories       85.39  627.6165 2019-03-25
# 299-46-1805       Sports and travel       93.72  590.4360 2019-01-15
# 750-67-8428       Health and beauty       74.69  548.9715 2019-01-05
# 656-95-9349       Health and beauty       68.93  506.6355 2019-03-11
# 123-19-1176       Health and beauty       58.22  489.0480 2019-01-27
# 765-26-6951       Sports and travel       72.61  457.4430 2019-01-01
# 252-56-2699      Food and beverages       43.19  453.4950 2019-02-07
# 355-53-5943  Electronic accessories       68.84  433.6920 2019-02-25
# 631-41-3108      Home and lifestyle       46.33  340.5255 2019-03-03
# 365-64-0515  Electronic accessories       46.95  246.4875 2019-02-12
# 692-92-5582      Food and beverages       54.84  172.7460 2019-02-20
# 329-62-1586      Food and beverages       54.67  172.2105 2019-01-21
# 529-56-3974  Electronic accessories       25.51  107.1420 2019-03-09
# 226-31-3081  Electronic accessories       15.28   80.2200 2019-03-08
# 665-32-9167       Health and beauty       36.26   76.1460 2019-01-10
# 351-62-0822     Fashion accessories       14.48   60.8160 2019-02-06
#
#             payment_method  rating
# invoice_id
# 315-22-5665        Ewallet     8.0
# 829-34-3910           Cash     5.7
# 373-73-7910        Ewallet     5.3
# 699-14-3026        Ewallet     4.1
# 299-46-1805           Cash     4.5
# 750-67-8428        Ewallet     9.1
# 656-95-9349    Credit card     4.6
# 123-19-1176        Ewallet     8.4
# 765-26-6951    Credit card     6.9
# 252-56-2699        Ewallet     8.2
# 355-53-5943        Ewallet     5.8
# 631-41-3108    Credit card     7.4
# 365-64-0515        Ewallet     7.1
# 692-92-5582    Credit card     5.9
# 329-62-1586    Credit card     8.6
# 529-56-3974           Cash     6.8
# 226-31-3081           Cash     9.6
# 665-32-9167    Credit card     7.2
# 351-62-0822        Ewallet     4.5

# %%
df_new.loc['315-22-5665' : '299-46-1805']
# Out:
#             branch          city customer_type  age  gender  \
# invoice_id
# 315-22-5665      D  Philadelphia        Normal   33  Female
# 829-34-3910      C     San Diego        Normal   24  Female
# 373-73-7910      A       Chicago        Normal   52    Male
# 699-14-3026      B  Philadelphia        Normal   54    Male
# 299-46-1805      B      New York        Member   39  Female
#
#                        product_line  unit_price     total       date  \
# invoice_id
# 315-22-5665      Home and lifestyle       73.56  772.3800 2019-02-24
# 829-34-3910       Health and beauty       71.38  749.4900 2019-03-29
# 373-73-7910       Sports and travel       86.31  634.3785 2019-02-08
# 699-14-3026  Electronic accessories       85.39  627.6165 2019-03-25
# 299-46-1805       Sports and travel       93.72  590.4360 2019-01-15
#
#             payment_method  rating
# invoice_id
# 315-22-5665        Ewallet     8.0
# 829-34-3910           Cash     5.7
# 373-73-7910        Ewallet     5.3
# 699-14-3026        Ewallet     4.1
# 299-46-1805           Cash     4.5

# %% [markdown]
# 6. **Indexing**: Select the "city" and "product_line" columns for transactions where the payment method is "Ewallet".

# %%
df[df['payment_method'] == 'Ewallet'][['city', 'product_line']]
# Out:
#             city            product_line
# 7   Philadelphia      Home and lifestyle
# 4        Chicago       Sports and travel
# 5   Philadelphia  Electronic accessories
# 0       San Jose       Health and beauty
# 3       New York       Health and beauty
# 13       Chicago      Food and beverages
# 6    Los Angeles  Electronic accessories
# 12      New York  Electronic accessories
# 10       Chicago     Fashion accessories

# %%
df_2 = df[df['payment_method'] == 'Ewallet']
df_2[['city', 'product_line']]
# Out:
#             city            product_line
# 7   Philadelphia      Home and lifestyle
# 4        Chicago       Sports and travel
# 5   Philadelphia  Electronic accessories
# 0       San Jose       Health and beauty
# 3       New York       Health and beauty
# 13       Chicago      Food and beverages
# 6    Los Angeles  Electronic accessories
# 12      New York  Electronic accessories
# 10       Chicago     Fashion accessories

# %% [markdown]
# 7. **Exporting**: Export the DataFrame to a new CSV file named "invoice_data.csv".

# %%
df.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'customer_type', 'age', 'gender',
#        'product_line', 'unit_price', 'total', 'date', 'payment_method',
#        'rating'],
#       dtype='object')

# %%
df[['invoice_id', 'branch', 'city', 'total', 'date', 'payment_method']].to_csv('invoice_data.csv', sep=',', index=None)

# %%
df[['invoice_id', 'branch', 'city', 'total', 'date', 'payment_method']].to_excel('invoice_data.xlsx', index=None, header=None)

# %% [markdown]
# 9. **Basics Operation**: Use `df.info` to display information about the DataFrame, including the number of non-null entries in each column.

# %%
# importing excel file without header

# %%
df_id = pd.read_excel('invoice_data.xlsx', header=None, names=['id', 'branch', 'country', 'total', 'date', 'p-type'])

# %%
df_id.head()
# Out:
#             id branch       country     total       date   p-type
# 0  315-22-5665      D  Philadelphia  772.3800 2019-02-24  Ewallet
# 1  829-34-3910      C     San Diego  749.4900 2019-03-29     Cash
# 2  373-73-7910      A       Chicago  634.3785 2019-02-08  Ewallet
# 3  699-14-3026      B  Philadelphia  627.6165 2019-03-25  Ewallet
# 4  299-46-1805      B      New York  590.4360 2019-01-15     Cash
