# %% [markdown]
# ### Day 16 of 30 days Python
# **Pandas**
#
# [Learn More](https://pandas.pydata.org/docs/index.html)
#
# -- DataFrame
# -- Importing data from csv, excel
# -- Filtering
# -- Sorting
# -- Indexing
# -- Exporting as csv, excel
#
# **Basics Pandas Operation**
# -- `head()`
# -- `tail()`
# -- `df.info`
# -- `df.dtype`
# -- `loc` and `iloc`

# %%
import pandas as pd
import openpyxl # xlsx
import xlrd # xls

# %%
import pandas as pd
import openpyxl #xlsx
import xlrd # xls

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
apple_data = {"iphones" : ['iPhone 12', 'iPhone 13', 'iPhone 15', 'iPhone 16'],
"price": [799, 899, 999, 1299],
"release-year": [2021, 2022, 2023, 2024]
}

type(apple_data)
# Out:
# dict

# %%
apple_df = pd.DataFrame(apple_data, index=[1, 3, 5, 9])
apple_df
# Out:
#      iphones  price  release-year
# 1  iPhone 12    799          2021
# 3  iPhone 13    899          2022
# 5  iPhone 15    999          2023
# 9  iPhone 16   1299          2024

# %%
f_df = pd.DataFrame(
    {
    'fruits_name' : ['Apple', 'Banana', 'Cherry', 'Mango'],
    'price' : [25, 18, 35, 15]
    }
    )
f_df
# Out:
#   fruits_name  price
# 0       Apple     25
# 1      Banana     18
# 2      Cherry     35
# 3       Mango     15

# %%
fruits = {
    'fruits_name' : ['Apple', 'Banana', 'Cherry', 'Mango'],
    'price' : [25, 18, 35, 15]
}

# %%
fruits.keys()
# Out:
# dict_keys(['fruits_name', 'price'])

# %%
fruits.values()
# Out:
# dict_values([['Apple', 'Banana', 'Cherry', 'Mango'], [25, 18, 35, 15]])

# %%
fruits.items()
# Out:
# dict_items([('fruits_name', ['Apple', 'Banana', 'Cherry', 'Mango']), ('price', [25, 18, 35, 15])])

# %%
fruits['price']
# Out:
# [25, 18, 35, 15]

# %% [markdown]
# #### Working with csv datasets

# %%
df_emp = pd.read_csv('day16_sample_emp.csv')

# %%
# df_emp = pd.read_csv('day16_sample_emp.csv', index_col = 'ID')

# %%
df_emp
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02002            Kai Le  Engineering   $92,368    47
# E02003      Robert Patel        Sales   $45,703    58
# E02004        Cameron Lo           IT   $83,576    34
# E02005   Harper Castillo           IT   $98,062    39
# E02008           Jade Hu   Accounting   $89,744    58
# E02009       Miles Chang      Finance   $69,674    62
# E02010     Gianna Holmes           IT   $97,630    38
# E02011    Jameson Thomas      Finance  $105,879    52
# E02012      Jameson Pena           IT   $40,499    49
# E02013          Bella Wu      Finance   $71,418    63
# E02014         Jose Wong           IT  $150,558    45
# E02015  Lucas Richardson    Marketing  $118,912    36
# E02016       Jacob Moore    Marketing  $131,422    42
# E02017           Luna Lu           IT   $64,208    62
# E02018        Bella Tran  Engineering  $254,486    45
# E02019          Ivy Chau        Sales   $54,811    61
# ...

# %%
df_emp.head(10)
# Out:
#               Full Name   Department     Salary  Age
# ID
# E02002           Kai Le  Engineering   $92,368    47
# E02003     Robert Patel        Sales   $45,703    58
# E02004       Cameron Lo           IT   $83,576    34
# E02005  Harper Castillo           IT   $98,062    39
# E02008          Jade Hu   Accounting   $89,744    58
# E02009      Miles Chang      Finance   $69,674    62
# E02010    Gianna Holmes           IT   $97,630    38
# E02011   Jameson Thomas      Finance  $105,879    52
# E02012     Jameson Pena           IT   $40,499    49
# E02013         Bella Wu      Finance   $71,418    63

# %%
df_emp.tail()
# Out:
#         ID         Full Name  Department     Salary  Age
# 16  E02020      Jordan Kumar          IT   $95,729    29
# 17  E02021  Sophia Gutierrez  Accounting  $102,649    63
# 18  E02022          Eli Dang  Accounting  $122,875    45
# 19  E02023     Lillian Lewis          IT   $83,323    43
# 20  E02024      Serenity Cao       Sales   $66,721    31

# %%
df_emp.columns
# Out:
# Index(['ID', 'Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          21 non-null     object
#  1   Full Name   21 non-null     object
#  2   Department  21 non-null     object
#  3   Salary      21 non-null     object
#  4   Age         21 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 972.0+ bytes

# %%
df_emp.dtypes
# Out:
# ID            object
# Full Name     object
# Department    object
# Salary        object
# Age            int64
# dtype: object

# %%
# df_emp.set_index('ID')
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02002            Kai Le  Engineering   $92,368    47
# E02003      Robert Patel        Sales   $45,703    58
# E02004        Cameron Lo           IT   $83,576    34
# E02005   Harper Castillo           IT   $98,062    39
# E02008           Jade Hu   Accounting   $89,744    58
# E02009       Miles Chang      Finance   $69,674    62
# E02010     Gianna Holmes           IT   $97,630    38
# E02011    Jameson Thomas      Finance  $105,879    52
# E02012      Jameson Pena           IT   $40,499    49
# E02013          Bella Wu      Finance   $71,418    63
# E02014         Jose Wong           IT  $150,558    45
# E02015  Lucas Richardson    Marketing  $118,912    36
# E02016       Jacob Moore    Marketing  $131,422    42
# E02017           Luna Lu           IT   $64,208    62
# E02018        Bella Tran  Engineering  $254,486    45
# E02019          Ivy Chau        Sales   $54,811    61
# ...

# %% [markdown]
# ### Sorting

# %%
df_emp.columns
# Out:
# Index(['Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
df_emp.sort_values(by = ['Full Name', 'Age'], ascending = [True, True])
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02018        Bella Tran  Engineering  $254,486    45
# E02013          Bella Wu      Finance   $71,418    63
# E02004        Cameron Lo           IT   $83,576    34
# E02022          Eli Dang   Accounting  $122,875    45
# E02010     Gianna Holmes           IT   $97,630    38
# E02005   Harper Castillo           IT   $98,062    39
# E02019          Ivy Chau        Sales   $54,811    61
# E02016       Jacob Moore    Marketing  $131,422    42
# E02008           Jade Hu   Accounting   $89,744    58
# E02012      Jameson Pena           IT   $40,499    49
# E02011    Jameson Thomas      Finance  $105,879    52
# E02020      Jordan Kumar           IT   $95,729    29
# E02014         Jose Wong           IT  $150,558    45
# E02002            Kai Le  Engineering   $92,368    47
# E02023     Lillian Lewis           IT   $83,323    43
# E02015  Lucas Richardson    Marketing  $118,912    36
# ...

# %%
df_emp.sort_index(ascending = False)
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02024      Serenity Cao        Sales   $66,721    31
# E02023     Lillian Lewis           IT   $83,323    43
# E02022          Eli Dang   Accounting  $122,875    45
# E02021  Sophia Gutierrez   Accounting  $102,649    63
# E02020      Jordan Kumar           IT   $95,729    29
# E02019          Ivy Chau        Sales   $54,811    61
# E02018        Bella Tran  Engineering  $254,486    45
# E02017           Luna Lu           IT   $64,208    62
# E02016       Jacob Moore    Marketing  $131,422    42
# E02015  Lucas Richardson    Marketing  $118,912    36
# E02014         Jose Wong           IT  $150,558    45
# E02013          Bella Wu      Finance   $71,418    63
# E02012      Jameson Pena           IT   $40,499    49
# E02011    Jameson Thomas      Finance  $105,879    52
# E02010     Gianna Holmes           IT   $97,630    38
# E02009       Miles Chang      Finance   $69,674    62
# ...

# %% [markdown]
# ### Filtering

# %%
df_emp.columns
# Out:
# Index(['Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
# df = df_emp[['Full Name', 'Department', 'Age']]

# %%
df
# Out:
#                Full Name   Department  Age
# ID
# E02002            Kai Le  Engineering   47
# E02003      Robert Patel        Sales   58
# E02004        Cameron Lo           IT   34
# E02005   Harper Castillo           IT   39
# E02008           Jade Hu   Accounting   58
# E02009       Miles Chang      Finance   62
# E02010     Gianna Holmes           IT   38
# E02011    Jameson Thomas      Finance   52
# E02012      Jameson Pena           IT   49
# E02013          Bella Wu      Finance   63
# E02014         Jose Wong           IT   45
# E02015  Lucas Richardson    Marketing   36
# E02016       Jacob Moore    Marketing   42
# E02017           Luna Lu           IT   62
# E02018        Bella Tran  Engineering   45
# E02019          Ivy Chau        Sales   61
# E02020      Jordan Kumar           IT   29
# E02021  Sophia Gutierrez   Accounting   63
# E02022          Eli Dang   Accounting   45
# E02023     Lillian Lewis           IT   43
# E02024      Serenity Cao        Sales   31

# %%
df[df['Age'] > 50]
# Out:
#                Full Name  Department  Age
# ID
# E02003      Robert Patel       Sales   58
# E02008           Jade Hu  Accounting   58
# E02009       Miles Chang     Finance   62
# E02011    Jameson Thomas     Finance   52
# E02013          Bella Wu     Finance   63
# E02017           Luna Lu          IT   62
# E02019          Ivy Chau       Sales   61
# E02021  Sophia Gutierrez  Accounting   63

# %%
# All employees who are from finance and age > 60
df[(df['Department'] == 'Finance') & (df['Age'] > 60)]
# Out:
#           Full Name Department  Age
# ID
# E02009  Miles Chang    Finance   62
# E02013     Bella Wu    Finance   63

# %% [markdown]
# **loc and iloc**
#
# This is used to select rows single or multiple rows together based on index
#
# index can be named index or int index
#
# `loc` -- Label column -- name column index
#
# `iloc` -- int column data -- index

# %%
df
# Out:
#                Full Name   Department  Age
# ID
# E02002            Kai Le  Engineering   47
# E02003      Robert Patel        Sales   58
# E02004        Cameron Lo           IT   34
# E02005   Harper Castillo           IT   39
# E02008           Jade Hu   Accounting   58
# E02009       Miles Chang      Finance   62
# E02010     Gianna Holmes           IT   38
# E02011    Jameson Thomas      Finance   52
# E02012      Jameson Pena           IT   49
# E02013          Bella Wu      Finance   63
# E02014         Jose Wong           IT   45
# E02015  Lucas Richardson    Marketing   36
# E02016       Jacob Moore    Marketing   42
# E02017           Luna Lu           IT   62
# E02018        Bella Tran  Engineering   45
# E02019          Ivy Chau        Sales   61
# E02020      Jordan Kumar           IT   29
# E02021  Sophia Gutierrez   Accounting   63
# E02022          Eli Dang   Accounting   45
# E02023     Lillian Lewis           IT   43
# E02024      Serenity Cao        Sales   31

# %%
df_emp
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02002            Kai Le  Engineering   $92,368    47
# E02003      Robert Patel        Sales   $45,703    58
# E02004        Cameron Lo           IT   $83,576    34
# E02005   Harper Castillo           IT   $98,062    39
# E02008           Jade Hu   Accounting   $89,744    58
# E02009       Miles Chang      Finance   $69,674    62
# E02010     Gianna Holmes           IT   $97,630    38
# E02011    Jameson Thomas      Finance  $105,879    52
# E02012      Jameson Pena           IT   $40,499    49
# E02013          Bella Wu      Finance   $71,418    63
# E02014         Jose Wong           IT  $150,558    45
# E02015  Lucas Richardson    Marketing  $118,912    36
# E02016       Jacob Moore    Marketing  $131,422    42
# E02017           Luna Lu           IT   $64,208    62
# E02018        Bella Tran  Engineering  $254,486    45
# E02019          Ivy Chau        Sales   $54,811    61
# ...

# %%
df.iloc[7]
# Out:
# Full Name     Jameson Thomas
# Department           Finance
# Age                       52
# Name: E02011, dtype: object

# %%
emp_index_df = df_emp.set_index('Department')

# %%
emp_index_df
# Out:
#                     Full Name     Salary  Age
# Department
# Engineering            Kai Le   $92,368    47
# Sales            Robert Patel   $45,703    58
# IT                 Cameron Lo   $83,576    34
# IT            Harper Castillo   $98,062    39
# Accounting            Jade Hu   $89,744    58
# Finance           Miles Chang   $69,674    62
# IT              Gianna Holmes   $97,630    38
# Finance        Jameson Thomas  $105,879    52
# IT               Jameson Pena   $40,499    49
# Finance              Bella Wu   $71,418    63
# IT                  Jose Wong  $150,558    45
# Marketing    Lucas Richardson  $118,912    36
# Marketing         Jacob Moore  $131,422    42
# IT                    Luna Lu   $64,208    62
# Engineering        Bella Tran  $254,486    45
# Sales                Ivy Chau   $54,811    61
# IT               Jordan Kumar   $95,729    29
# Accounting   Sophia Gutierrez  $102,649    63
# Accounting           Eli Dang  $122,875    45
# ...

# %%
emp_index_df.loc['IT']
# Out:
#                 ID        Full Name     Salary  Age
# Department
# IT          E02004       Cameron Lo   $83,576    34
# IT          E02005  Harper Castillo   $98,062    39
# IT          E02010    Gianna Holmes   $97,630    38
# IT          E02012     Jameson Pena   $40,499    49
# IT          E02014        Jose Wong  $150,558    45
# IT          E02017          Luna Lu   $64,208    62
# IT          E02020     Jordan Kumar   $95,729    29
# IT          E02023    Lillian Lewis   $83,323    43

# %%
df_emp[df_emp['Department'] == 'IT']
# Out:
#         ID        Full Name Department     Salary  Age
# 2   E02004       Cameron Lo         IT   $83,576    34
# 3   E02005  Harper Castillo         IT   $98,062    39
# 6   E02010    Gianna Holmes         IT   $97,630    38
# 8   E02012     Jameson Pena         IT   $40,499    49
# 10  E02014        Jose Wong         IT  $150,558    45
# 13  E02017          Luna Lu         IT   $64,208    62
# 16  E02020     Jordan Kumar         IT   $95,729    29
# 19  E02023    Lillian Lewis         IT   $83,323    43

# %%
apple_df.to_csv('apple_df.csv', index=False, header=None)

# %%
apple_df.to_csv('apple_df.xlsx')

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
apple_data = {
    "iphones" :['iPhone 12', 'iPhone 13', 'iPhone 15', 'iPhone 16'],
    "price" : [799, 899, 999, 1299],
    "release_year" : [2021, 2022, 2023, 2024]
    }

type(apple_data)
# Out:
# dict

# %%
apple_df = pd.DataFrame(apple_data, index=[1, 3, 5, 9])
apple_df
# Out:
#      iphones  price  release_year
# 1  iPhone 12    799          2021
# 3  iPhone 13    899          2022
# 5  iPhone 15    999          2023
# 9  iPhone 16   1299          2024

# %%
apple_df.to_excel('apple_data.xlsx')

# %%
apple_df.to_csv('apple_df.csv', index=False, header=None)

# %%
f_df = pd.DataFrame(
    {
    "fruits_name" : ['Apple', 'Banana', 'Dates', 'Mango'],
    "price" : [25, 18, 35, 15]
    }
    )

# %% [markdown]
# #### Working with csv datasets

# %%
df_emp = pd.read_csv('sample_emp.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_emp = pd.read_csv('sample_emp.csv')
#
# File c:\Users\Administrator\Documents\Vscode\my_venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df_emp.head()
# Out:
#        ID        Full Name   Department    Salary  Age
# 0  E02002           Kai Le  Engineering  $92,368    47
# 1  E02003     Robert Patel        Sales  $45,703    58
# 2  E02004       Cameron Lo           IT  $83,576    34
# 3  E02005  Harper Castillo           IT  $98,062    39
# 4  E02008          Jade Hu   Accounting  $89,744    58

# %%
df_emp.tail()
# Out:
#         ID         Full Name  Department     Salary  Age
# 16  E02020      Jordan Kumar          IT   $95,729    29
# 17  E02021  Sophia Gutierrez  Accounting  $102,649    63
# 18  E02022          Eli Dang  Accounting  $122,875    45
# 19  E02023     Lillian Lewis          IT   $83,323    43
# 20  E02024      Serenity Cao       Sales   $66,721    31

# %%
df_emp.head(10)
# Out:
#        ID        Full Name   Department     Salary  Age
# 0  E02002           Kai Le  Engineering   $92,368    47
# 1  E02003     Robert Patel        Sales   $45,703    58
# 2  E02004       Cameron Lo           IT   $83,576    34
# 3  E02005  Harper Castillo           IT   $98,062    39
# 4  E02008          Jade Hu   Accounting   $89,744    58
# 5  E02009      Miles Chang      Finance   $69,674    62
# 6  E02010    Gianna Holmes           IT   $97,630    38
# 7  E02011   Jameson Thomas      Finance  $105,879    52
# 8  E02012     Jameson Pena           IT   $40,499    49
# 9  E02013         Bella Wu      Finance   $71,418    63

# %%
df_emp.columns
# Out:
# Index(['ID', 'Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          21 non-null     object
#  1   Full Name   21 non-null     object
#  2   Department  21 non-null     object
#  3   Salary      21 non-null     object
#  4   Age         21 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 972.0+ bytes

# %%
df_emp.dtypes
# Out:
# ID            object
# Full Name     object
# Department    object
# Salary        object
# Age            int64
# dtype: object

# %%
df_emp.set_index('ID')
# Out:
#                Full Name   Department     Salary  Age
# ID
# E02002            Kai Le  Engineering   $92,368    47
# E02003      Robert Patel        Sales   $45,703    58
# E02004        Cameron Lo           IT   $83,576    34
# E02005   Harper Castillo           IT   $98,062    39
# E02008           Jade Hu   Accounting   $89,744    58
# E02009       Miles Chang      Finance   $69,674    62
# E02010     Gianna Holmes           IT   $97,630    38
# E02011    Jameson Thomas      Finance  $105,879    52
# E02012      Jameson Pena           IT   $40,499    49
# E02013          Bella Wu      Finance   $71,418    63
# E02014         Jose Wong           IT  $150,558    45
# E02015  Lucas Richardson    Marketing  $118,912    36
# E02016       Jacob Moore    Marketing  $131,422    42
# E02017           Luna Lu           IT   $64,208    62
# E02018        Bella Tran  Engineering  $254,486    45
# E02019          Ivy Chau        Sales   $54,811    61
# ...

# %% [markdown]
# **Sorting**

# %%
df_emp.columns
# Out:
# Index(['ID', 'Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
df_emp.sort_values(by=['Full Name', 'Age'], ascending=[True, True])
# Out:
#         ID         Full Name   Department     Salary  Age
# 14  E02018        Bella Tran  Engineering  $254,486    45
# 9   E02013          Bella Wu      Finance   $71,418    63
# 2   E02004        Cameron Lo           IT   $83,576    34
# 18  E02022          Eli Dang   Accounting  $122,875    45
# 6   E02010     Gianna Holmes           IT   $97,630    38
# 3   E02005   Harper Castillo           IT   $98,062    39
# 15  E02019          Ivy Chau        Sales   $54,811    61
# 12  E02016       Jacob Moore    Marketing  $131,422    42
# 4   E02008           Jade Hu   Accounting   $89,744    58
# 8   E02012      Jameson Pena           IT   $40,499    49
# 7   E02011    Jameson Thomas      Finance  $105,879    52
# 16  E02020      Jordan Kumar           IT   $95,729    29
# 10  E02014         Jose Wong           IT  $150,558    45
# 0   E02002            Kai Le  Engineering   $92,368    47
# 19  E02023     Lillian Lewis           IT   $83,323    43
# ...

# %%
df_emp.sort_index(ascending=False)
# Out:
#         ID         Full Name   Department     Salary  Age
# 20  E02024      Serenity Cao        Sales   $66,721    31
# 19  E02023     Lillian Lewis           IT   $83,323    43
# 18  E02022          Eli Dang   Accounting  $122,875    45
# 17  E02021  Sophia Gutierrez   Accounting  $102,649    63
# 16  E02020      Jordan Kumar           IT   $95,729    29
# 15  E02019          Ivy Chau        Sales   $54,811    61
# 14  E02018        Bella Tran  Engineering  $254,486    45
# 13  E02017           Luna Lu           IT   $64,208    62
# 12  E02016       Jacob Moore    Marketing  $131,422    42
# 11  E02015  Lucas Richardson    Marketing  $118,912    36
# 10  E02014         Jose Wong           IT  $150,558    45
# 9   E02013          Bella Wu      Finance   $71,418    63
# 8   E02012      Jameson Pena           IT   $40,499    49
# 7   E02011    Jameson Thomas      Finance  $105,879    52
# 6   E02010     Gianna Holmes           IT   $97,630    38
# ...

# %% [markdown]
# **Filtering**

# %%
df_emp.columns
# Out:
# Index(['ID', 'Full Name', 'Department', 'Salary', 'Age'], dtype='object')

# %%
df = df_emp[['Full Name', 'Department', 'Age']]

# %%
df[df['Age'] > 55]
# Out:
#            Full Name  Department  Age
# 1       Robert Patel       Sales   58
# 4            Jade Hu  Accounting   58
# 5        Miles Chang     Finance   62
# 9           Bella Wu     Finance   63
# 13           Luna Lu          IT   62
# 15          Ivy Chau       Sales   61
# 17  Sophia Gutierrez  Accounting   63

# %%
df[df['Age'] > 50]
# Out:
#            Full Name  Department  Age
# 1       Robert Patel       Sales   58
# 4            Jade Hu  Accounting   58
# 5        Miles Chang     Finance   62
# 7     Jameson Thomas     Finance   52
# 9           Bella Wu     Finance   63
# 13           Luna Lu          IT   62
# 15          Ivy Chau       Sales   61
# 17  Sophia Gutierrez  Accounting   63

# %%
# All emp who from finance and age > 60
df[(df['Department'] == 'Finance') & (df['Age'] > 60)]
# Out:
#      Full Name Department  Age
# 5  Miles Chang    Finance   62
# 9     Bella Wu    Finance   63

# %% [markdown]
# **loc and iloc**
#
# This is used to select rows single or multiple rows together based on index
# index can be named index or int index
#
# `loc` -- Label column -- name colum index
# `iloc` -- int column data -- index

# %%
df.iloc[7:10]
# Out:
#         Full Name Department  Age
# 7  Jameson Thomas    Finance   52
# 8    Jameson Pena         IT   49
# 9        Bella Wu    Finance   63

# %%
emp_index_df = df_emp.set_index('Department')

# %%
df_emp
# Out:
#         ID         Full Name   Department     Salary  Age
# 0   E02002            Kai Le  Engineering   $92,368    47
# 1   E02003      Robert Patel        Sales   $45,703    58
# 2   E02004        Cameron Lo           IT   $83,576    34
# 3   E02005   Harper Castillo           IT   $98,062    39
# 4   E02008           Jade Hu   Accounting   $89,744    58
# 5   E02009       Miles Chang      Finance   $69,674    62
# 6   E02010     Gianna Holmes           IT   $97,630    38
# 7   E02011    Jameson Thomas      Finance  $105,879    52
# 8   E02012      Jameson Pena           IT   $40,499    49
# 9   E02013          Bella Wu      Finance   $71,418    63
# 10  E02014         Jose Wong           IT  $150,558    45
# 11  E02015  Lucas Richardson    Marketing  $118,912    36
# 12  E02016       Jacob Moore    Marketing  $131,422    42
# 13  E02017           Luna Lu           IT   $64,208    62
# 14  E02018        Bella Tran  Engineering  $254,486    45
# ...

# %%
df_emp
# Out:
#         ID         Full Name   Department     Salary  Age
# 0   E02002            Kai Le  Engineering   $92,368    47
# 1   E02003      Robert Patel        Sales   $45,703    58
# 2   E02004        Cameron Lo           IT   $83,576    34
# 3   E02005   Harper Castillo           IT   $98,062    39
# 4   E02008           Jade Hu   Accounting   $89,744    58
# 5   E02009       Miles Chang      Finance   $69,674    62
# 6   E02010     Gianna Holmes           IT   $97,630    38
# 7   E02011    Jameson Thomas      Finance  $105,879    52
# 8   E02012      Jameson Pena           IT   $40,499    49
# 9   E02013          Bella Wu      Finance   $71,418    63
# 10  E02014         Jose Wong           IT  $150,558    45
# 11  E02015  Lucas Richardson    Marketing  $118,912    36
# 12  E02016       Jacob Moore    Marketing  $131,422    42
# 13  E02017           Luna Lu           IT   $64,208    62
# 14  E02018        Bella Tran  Engineering  $254,486    45
# ...

# %%
emp_index_df.loc['IT']
# Out:
#                 ID        Full Name     Salary  Age
# Department
# IT          E02004       Cameron Lo   $83,576    34
# IT          E02005  Harper Castillo   $98,062    39
# IT          E02010    Gianna Holmes   $97,630    38
# IT          E02012     Jameson Pena   $40,499    49
# IT          E02014        Jose Wong  $150,558    45
# IT          E02017          Luna Lu   $64,208    62
# IT          E02020     Jordan Kumar   $95,729    29
# IT          E02023    Lillian Lewis   $83,323    43

# %%
df_emp[df_emp['Department'] == 'IT']
# Out:
#         ID        Full Name Department     Salary  Age
# 2   E02004       Cameron Lo         IT   $83,576    34
# 3   E02005  Harper Castillo         IT   $98,062    39
# 6   E02010    Gianna Holmes         IT   $97,630    38
# 8   E02012     Jameson Pena         IT   $40,499    49
# 10  E02014        Jose Wong         IT  $150,558    45
# 13  E02017          Luna Lu         IT   $64,208    62
# 16  E02020     Jordan Kumar         IT   $95,729    29
# 19  E02023    Lillian Lewis         IT   $83,323    43

# %%
apple_new_df = apple_df.set_index('iphones')

# %%
apple_new_df.loc['iPhone 15']
# Out:
# price            999
# release_year    2023
# Name: iPhone 15, dtype: int64

# %%
apple_new_df
# Out:
#            price  release_year
# iphones
# iPhone 12    799          2021
# iPhone 13    899          2022
# iPhone 15    999          2023
# iPhone 16   1299          2024
